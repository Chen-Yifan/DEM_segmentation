', '151_129_predict.npy', '152_056_predict.npy', '152_057_predict.npy', '152_060_predict.npy', '152_061_predict.npy', '152_062_predict.npy', '152_108_predict.npy', '152_109_predict.npy', '152_112_predict.npy', '152_113_predict.npy', '153_056_predict.npy', '153_057_predict.npy', '153_058_predict.npy', '153_105_predict.npy', '153_106_predict.npy', '153_107_predict.npy', '153_108_predict.npy', '153_109_predict.npy', '153_131_predict.npy', '153_132_predict.npy', '154_056_predict.npy', '154_057_predict.npy', '154_058_predict.npy', '154_059_predict.npy', '154_105_predict.npy', '154_106_predict.npy', '154_107_predict.npy', '154_130_predict.npy', '154_131_predict.npy', '154_132_predict.npy', '155_056_predict.npy', '155_057_predict.npy', '155_058_predict.npy', '155_059_predict.npy', '155_082_predict.npy', '155_083_predict.npy', '155_130_predict.npy', '155_131_predict.npy', '155_132_predict.npy', '156_082_predict.npy', '156_083_predict.npy', '156_085_predict.npy', '156_086_predict.npy', '156_087_predict.npy', '157_085_predict.npy', '157_086_predict.npy', '157_087_predict.npy', '158_112_predict.npy', '158_113_predict.npy', '158_124_predict.npy', '158_125_predict.npy', '158_126_predict.npy', '159_112_predict.npy', '159_113_predict.npy', '159_124_predict.npy', '159_125_predict.npy', '159_126_predict.npy', '160_073_predict.npy', '160_074_predict.npy', '160_083_predict.npy', '160_084_predict.npy', '160_085_predict.npy', '160_112_predict.npy', '160_113_predict.npy', '160_118_predict.npy', '160_119_predict.npy', '160_124_predict.npy', '160_125_predict.npy', '160_126_predict.npy', '160_145_predict.npy', '160_146_predict.npy', '160_147_predict.npy', '161_073_predict.npy', '161_074_predict.npy', '161_083_predict.npy', '161_084_predict.npy', '161_085_predict.npy', '161_108_predict.npy', '161_109_predict.npy', '161_118_predict.npy', '161_119_predict.npy ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
def vis(i):
    pred = np.load(os.path.join(results_dir,results_files[i]))
    print(pred.shape)
    orig =np.load(os.path.join(test_mask_dir,masks_files[i]))
    orig = orig[:,:,1]
    frame =np.load(os.path.join(test_frame_dir,frames_files[i]))
    print(masks_files[i])
#     print(frame[:,:,0])
    fig = plt.figure()
    f = plt.figure(1)
    plt.axis('off')
    plt.title('groundtruth')
    origplot = plt.imshow(orig,cmap='gray')
    g = plt.figure(2)
    plt.axis('off')
    plt.title('prediction')
    predplot = plt.imshow(pred,cmap='gray')
    a = plt.figure(3)
    plt.title('frame0')
    frame0 = plt.imshow(frame[:,:,0],cmap='gray',)
    b = plt.figure(4)
    plt.title('frame1')
    frame1 = plt.imshow(frame[:,:,1],cmap='gray')
    c = plt.figure(5)
    plt.title('frame2')
    frame2 = plt.imshow(frame[:,:,2],cmap='gray')
    d = plt.figure(6)
    plt.title('frame3')
    frame3 = plt.imshow(frame[:,:,3],cmap='gray')
    e = plt.figure(7)
    plt.title('frame4')
    frame4 = plt.imshow(frame[:,:,4],cmap='gray')
    f = plt.figure(8)
    plt.title('frame4')
    frame4 = plt.imshow(frame[:,:,5],cmap='gray')

    plt.show()

# %%
vis(605
   )
# Out:
# (128, 128)
# 191_102.npy

# %%
def vis_multi(i):
    dist= np.load(os.path.join(results_dir,results_files[2*i+0]))
    binary= np.load(os.path.join(results_dir,results_files[2*i+1]))
    print(results_files[2*i+1], frames_files[i])
    print(dist.shape,binary.shape)
    orig =np.load(os.path.join(test_mask_dir,masks_files[2*i+0]))
    orig = orig[:,:,1]
    frame =np.load(os.path.join(test_frame_dir,frames_files[i]))
    print(masks_files[i])
#     print(frame[:,:,0])
    fig = plt.figure()
    f = plt.figure(1)
    plt.axis('off')
#     plt.title('mask')
    origplot = plt.imshow(orig,cmap='gray')
    g = plt.figure(2)
    plt.axis('off')
    plt.title('distance_mask_pred')
    predplot = plt.imshow(dist,cmap='gray')
    h = plt.figure(3)
    plt.axis('off')
    plt.title('binary_mask_pred')
    binaryplot = plt.imshow(binary,cmap='gray')
    a = plt.figure(4)
    plt.axis('off')
    plt.title('frame0')
    frame0 = plt.imshow(frame[:,:,0],cmap='gray',)
    b = plt.figure(5)
    plt.axis('off')
    plt.title('frame1')
    frame1 = plt.imshow(frame[:,:,1],cmap='gray')
    c = plt.figure(6)
    plt.axis('off')
    plt.title('frame2')
    frame2 = plt.imshow(frame[:,:,2],cmap='gray')
    d = plt.figure(7)
    plt.axis('off')
    plt.title('frame3')
    frame3 = plt.imshow(frame[:,:,3],cmap='gray')
    e = plt.figure(8)
    plt.axis('off')
    plt.title('frame4')
    frame4 = plt.imshow(frame[:,:,4],cmap='gray')
    f = plt.figure(9)
    plt.axis('off')
#     plt.title('DEM')
    frame4 = plt.imshow(frame[:,:,5],cmap='gray')

    plt.show()

# %%
vis_multi(65
    
   )
# Out:
# 150_057_binary.npy 150_057.npy
# (128, 128) (128, 128)
# 150_057.npy

# %%
tot = 0
for i in range(len(frames_files)):
    orig =np.load(os.path.join(test_mask_dir,masks_files[i]))
    num = np.count_nonzero(orig == 1)
    tot += num/(256*256)

# %%
print(len(frames_files))
print(387/tot)
# Out:
# 774
# 0.5

# %%
imgplot = plt.imshow(orig0,cmap='gray')

# %%
imgplot = plt.imshow(pred0,cmap='gray')

# %%
imgplot = plt.imshow(orig1,cmap='gray')

# %%
imgplot = plt.imshow(pred1,cmap='gray')

# %%
imgplot = plt.imshow(orig2,cmap='gray')

# %%
imgplot = plt.imshow(pred2,cmap='gray')

# %% [markdown]
# # Plot

# %%
img_iou=mpimg.imread(os.path.join(plot_dir,'Mean_IoU.png'))
img_loss=mpimg.imread(os.path.join(plot_dir,'loss.png'))

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 8
fig_size[1] = 5
plt.rcParams["figure.figsize"] = fig_size
imgplot = plt.imshow(img_loss)
plt.axis('off')
# Out:
# (-0.5, 639.5, 479.5, -0.5)
