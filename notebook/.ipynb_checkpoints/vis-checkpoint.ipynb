_042_predict.npy', '078_043_predict.npy', '078_046_predict.npy', '078_047_predict.npy', '078_050_predict.npy', '078_076_predict.npy', '078_077_predict.npy', '078_082_predict.npy', '078_083_predict.npy', '078_091_predict.npy', '078_092_predict.npy', '078_093_predict.npy', '078_094_predict.npy', '078_095_predict.npy', '078_098_predict.npy', '079_024_predict.npy', '079_026_predict.npy', '079_040_predict.npy', '079_041_predict.npy', '079_042_predict.npy', '079_046_predict.npy', '079_065_predict.npy', '079_066_predict.npy', '079_070_predict.npy', '079_072_predict.npy', '079_074_predict.npy', '079_077_predict.npy', '079_078_predict.npy', '079_080_predict.npy', '079_082_predict.npy', '079_083_predict.npy', '079_087_predict.npy', '079_091_predict.npy', '079_098_predict.npy', '079_107_predict.npy', '079_108_predict.npy', '080_029_predict.npy', '080_052_predict.npy', '080_065_predict.npy', '080_066_predict.npy', '080_077_predict.npy', '080_078_predict.npy', '080_082_predict.npy', '080_083_predict.npy', '080_108_predict.npy', '081_024_predict.npy', '081_029_predict.npy', '081_041_predict.npy', '081_045_predict.npy', '081_046_predict.npy', '081_047_predict.npy', '081_063_predict.npy', '081_071_predict.npy', '081_074_predict.npy', '081_077_predict.npy', '081_078_predict.npy', '081_112_predict.npy', '082_027_predict.npy', '082_045_predict.npy', '082_046_predict.npy', '082_047_predict.npy', '082_050_predict.npy', '082_069_predict.npy', '082_072_predict.npy', '082_081_predict.npy', '082_086_predict.npy', '082_092_predict.npy', '082_094_predict.npy', '082_106_predict.npy', '082_107_predict.npy', '082_109_predict.npy', '083_019_predict.npy', '083_032_predict.npy', '083_034_predict.npy', '083_038_predict.npy', '083_043_predict.npy', '083_044_predict.npy', '083_050_predict.npy', '083_062_predict.npy', '083_074_predict.npy', '083_106_predict.npy', '083_107_predict.npy', '084_015_predict.npy ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
def vis(i):
    pred = np.load(os.path.join(results_dir,results_files[i]))
    print(pred.shape)
    orig =np.load(os.path.join(test_mask_dir,masks_files[i]))
    orig = orig[:,:,1]
    frame =np.load(os.path.join(test_frame_dir,frames_files[i]))
    print(masks_files[i])
#     print(frame[:,:,0])
    fig = plt.figure()
    f = plt.figure(1)
    plt.title('mask')
    origplot = plt.imshow(orig,cmap='gray')
    g = plt.figure(2)
    plt.title('prediction')
    predplot = plt.imshow(pred,cmap='gray')
    a = plt.figure(3)
    plt.title('frame0')
    frame0 = plt.imshow(frame[:,:,0],cmap='gray',)
    b = plt.figure(4)
    plt.title('frame1')
    frame1 = plt.imshow(frame[:,:,1],cmap='gray')
    c = plt.figure(5)
    plt.title('frame2')
    frame2 = plt.imshow(frame[:,:,2],cmap='gray')
    d = plt.figure(6)
    plt.title('frame3')
    frame3 = plt.imshow(frame[:,:,3],cmap='gray')
    e = plt.figure(7)
    plt.title('frame4')
    print(np.max(frame[:,:,4]),np.min(frame[:,:,4]),np.unique(frame[:,:,4]))
    frame4 = plt.imshow(frame[:,:,4],cmap='gray')
#     f = plt.figure(8)
#     plt.title('frame5')
#     frame4 = plt.imshow(frame[:,:,5],cmap='gray')

    plt.show()

# %%
vis(0
   )
# Out:
# (128, 128)
# 072_072.npy
# 0.648322 0.0

# %%
def vis_multi(i):
    dist= np.load(os.path.join(results_dir,results_files[2*i+0]))
    binary= np.load(os.path.join(results_dir,results_files[2*i+1]))
    print(dist.shape,binary.shape)
    orig =np.load(os.path.join(test_mask_dir,masks_files[2*i+0]))
    orig = orig[:,:,1]
    frame =np.load(os.path.join(test_frame_dir,frames_files[i]))
    print(masks_files[i])
#     print(frame[:,:,0])
    fig = plt.figure()
    f = plt.figure(1)
    plt.title('mask')
    origplot = plt.imshow(orig,cmap='gray')
    g = plt.figure(2)
    plt.title('dist')
    predplot = plt.imshow(dist,cmap='gray')
    h = plt.figure(3)
    plt.title('binary')
    binaryplot = plt.imshow(binary,cmap='gray')
    a = plt.figure(4)
    plt.title('frame0')
    frame0 = plt.imshow(frame[:,:,0],cmap='gray',)
    b = plt.figure(5)
    plt.title('frame1')
    frame1 = plt.imshow(frame[:,:,1],cmap='gray')
    c = plt.figure(6)
    plt.title('frame2')
    frame2 = plt.imshow(frame[:,:,2],cmap='gray')
    d = plt.figure(7)
    plt.title('frame3')
    frame3 = plt.imshow(frame[:,:,3],cmap='gray')
    e = plt.figure(8)
    plt.title('frame4')
    frame4 = plt.imshow(frame[:,:,4],cmap='gray')
    f = plt.figure(9)
    plt.title('frame4')
    frame4 = plt.imshow(frame[:,:,5],cmap='gray')

    plt.show()

# %%
vis_multi(102
    
   )
# Out:
# (128, 128) (128, 128)
# 152_113.npy

# %%
tot = 0
for i in range(len(frames_files)):
    orig =np.load(os.path.join(test_mask_dir,masks_files[i]))
    num = np.count_nonzero(orig == 1)
    tot += num/(256*256)

# %%
print(len(frames_files))
print(387/tot)
# Out:
# 774
# 0.5

# %%
imgplot = plt.imshow(orig0,cmap='gray')

# %%
imgplot = plt.imshow(pred0,cmap='gray')

# %%
imgplot = plt.imshow(orig1,cmap='gray')

# %%
imgplot = plt.imshow(pred1,cmap='gray')

# %%
imgplot = plt.imshow(orig2,cmap='gray')

# %%
imgplot = plt.imshow(pred2,cmap='gray')

# %% [markdown]
# # Plot

# %%
img_iou=mpimg.imread(os.path.join(plot_dir,'Mean_IoU.png'))
img_loss=mpimg.imread(os.path.join(plot_dir,'loss.png'))

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 8
fig_size[1] = 5
plt.rcParams["figure.figsize"] = fig_size
imgplot = plt.imshow(img_loss)
plt.axis('off')
# Out:
# (-0.5, 639.5, 479.5, -0.5)
