# %%
import os
frame_dir = '/home/yifanc3/dataset/data/selected/all_frames/'# iou = 69%
mask_dir = '/home/yifanc3/dataset/data/selected/all_masks/'

# plot_dir = '/home/yifanc3/segmentation_v2/DEM_segmentation/'


# results_dir = '/home/yifanc3/results/Model_norm/'
# test_mask_dir = '/home/yifanc3/results/resplit_orig_mask'
# plot_dir = '/home/yifanc3/segmentation_v2/DEM_segmentation/'
masks_files = os.listdir(mask_dir)
frames_files = os.listdir(frame_dir)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
mask0=np.load(os.path.join(mask_dir,masks_files[25]))
frame0=np.load(os.path.join(frame_dir,frames_files[25]))
print(frame0.shape)
# Out:
# (64, 64, 5)

# %%
fig = plt.figure()
a = plt.figure(1)
plt.title('frame0')
frame0 = plt.imshow(frame0[:,:,0],cmap='gray',)
b = plt.figure(2)
plt.title('frame1')
frame1 = plt.imshow(frame0[:,:,1],cmap='gray')
c = plt.figure(3)
plt.title('frame2')
frame2 = plt.imshow(frame0[:,:,2],cmap='gray')
d = plt.figure(4)
plt.title('frame3')
frame3 = plt.imshow(frame0[:,:,3],cmap='gray')
e = plt.figure(5)
plt.title('frame4')
frame4 = plt.imshow(frame0[:,:,4],cmap='gray')
f = plt.figure(6)
plt.title('mask')
origplot = plt.imshow(mask0,cmap='gray')


plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-eabeaacbecc8> in <module>
#       6 b = plt.figure(2)
#       7 plt.title('frame1')
# ----> 8 frame1 = plt.imshow(frame0[:,:,1],cmap='gray')
#       9 c = plt.figure(3)
#      10 plt.title('frame2')
#
# TypeError: 'AxesImage' object is not subscriptable

# %%
mask0=np.load(os.path.join(mask_dir,masks_files[2347]))
f = plt.figure(6)
plt.title('mask')
origplot = plt.imshow(mask0,cmap='gray')
