# %%
import os
frame_dir = '/home/yifanc3/dataset/npy/all_frames/'# iou = 69%
mask_dir = '/home/yifanc3/dataset/npy/all_masks/'

# plot_dir = '/home/yifanc3/segmentation_v2/DEM_segmentation/'

# results_dir = '/home/yifanc3/results/Model_norm/'
# test_mask_dir = '/home/yifanc3/results/resplit_orig_mask'
# plot_dir = '/home/yifanc3/segmentation_v2/DEM_segmentation/'
masks_files = os.listdir(mask_dir)
frames_files = os.listdir(frame_dir)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
for i in range(len(masks_files)):
    frame0=np.load(os.path.join(frame_dir,frames_files[i]))
    print(np.max(frame0[:,:,0]),np.max(frame0[:,:,1]),np.max(frame0[:,:,2]),np.max(frame0[:,:,3]),np.max(frame0[:,:,4]))
# Out:
# 72.19841 359.99664 48.77002 45.408752 50.35829
# 70.927 359.99664 48.77002 45.408752 50.35829
# 83.25064 359.99945 96.78003 55.65753 70.600296
# 71.78397 359.99515 42.54004 38.6463 43.144432
# 74.136696 359.9977 39.22998 32.325012 38.22065
# 81.87061 359.99393 80.86005 60.078735 69.98859
# 81.87061 359.99393 80.86005 60.078735 69.98859
# 81.87061 359.99915 80.86005 60.078735 69.98859
# 72.95803 359.99506 64.859985 64.505005 74.70922
# 63.82545 359.9973 22.960022 22.03125 24.818924
# 72.7019 359.9964 64.83002 64.31879 72.735344
# 68.10898 359.99573 47.539978 45.058716 50.538094
# 50.350315 359.99307 15.740051 10.290039 11.600975
# 66.61891 359.99866 25.98999 16.307495 17.524223
# 78.256226 359.99835 55.799988 54.075012 67.39376
# 78.256226 359.99835 49.630005 43.285034 48.26673
# 36.33532 359.99786 12.160034 9.327454 10.268539
# 8.140826 359.99222 1.7600098 0.89630127 0.9888077
# 77.80435 359.99493 60.360046 54.13257 61.273827
# 6.5400157 359.99078 1.4700317 0.7237549 0.8092041
# ...

# %%
fig = plt.figure()
a = plt.figure(1)
plt.title('frame0')
frame0 = plt.imshow(frame0[:,:,0],cmap='gray',)
b = plt.figure(2)
plt.title('frame1')
frame1 = plt.imshow(frame0[:,:,1],cmap='gray')
c = plt.figure(3)
plt.title('frame2')
frame2 = plt.imshow(frame0[:,:,2],cmap='gray')
d = plt.figure(4)
plt.title('frame3')
frame3 = plt.imshow(frame0[:,:,3],cmap='gray')
e = plt.figure(5)
plt.title('frame4')
frame4 = plt.imshow(frame0[:,:,4],cmap='gray')
f = plt.figure(6)
plt.title('mask')
origplot = plt.imshow(mask0,cmap='gray')


plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-eabeaacbecc8> in <module>
#       6 b = plt.figure(2)
#       7 plt.title('frame1')
# ----> 8 frame1 = plt.imshow(frame0[:,:,1],cmap='gray')
#       9 c = plt.figure(3)
#      10 plt.title('frame2')
#
# TypeError: 'AxesImage' object is not subscriptable

# %%
mask0=np.load(os.path.join(mask_dir,masks_files[2347]))
f = plt.figure(6)
plt.title('mask')
origplot = plt.imshow(mask0,cmap='gray')

# %%
from libtiff import TIFF
curpath = '/home/yifanc3/dataset/data'
tif = TIFF.open(curpath + '/mclean_roi.tif')
img = tif.read_image()
import numpy as np
np.max(img[:,:,0])

# %%
import numpy as np
np.max(img[:,:,0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-e3c697e7dc62> in <module>
#       1 import numpy as np
# ----> 2 np.max(img[:,:,0])
#
# IndexError: too many indices for array

# %%
np.max(img[:,:,1])

# %%
np.max(img[:,:,2])

# %%
np.max(img[:,:,3])

# %%
np.max(img[:,:,4])
