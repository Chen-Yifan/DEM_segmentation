# %%
import os
frame_dir = '/home/yifanc3/dataset/data/selected_128_overlap/all_frames_5m6b/'# iou = 69%
mask_dir = '/home/yifanc3/dataset/data/selected_128_overlap/all_masks_5m6b/'

# plot_dir = '/home/yifanc3/segmentation_v2/DEM_segmentation/'

# results_dir = '/home/yifanc3/results/Model_norm/'
# test_mask_dir = '/home/yifanc3/results/resplit_orig_mask'
# plot_dir = '/home/yifanc3/segmentation_v2/DEM_segmentation/'
masks_files = os.listdir(mask_dir)
frames_files = os.listdir(frame_dir)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

from skimage import measure

# %%
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-8-7206a54f1c36> in <module>()
#       6
#       7 # Find contours at a constant value of 0.8
# ----> 8 contours = measure.find_contours(orig, 0.8)
#       9
#      10 # Display the image and plot all contours found
#
# /usr/lib64/python2.7/site-packages/skimage/measure/_find_contours.pyc in find_contours(array, level, fully_connected, positive_orientation)
#     110     array = np.asarray(array, dtype=np.double)
#     111     if array.ndim != 2:
# --> 112         raise ValueError('Only 2D arrays are supported.')
#     113     level = float(level)
#     114     if (fully_connected not in _param_options or
#
# ValueError: Only 2D arrays are supported.

# %%
fig = plt.figure()
a = plt.figure(1)
plt.title('frame0')
frame0 = plt.imshow(frame0[:,:,0],cmap='gray',)
b = plt.figure(2)
plt.title('frame1')
frame1 = plt.imshow(frame0[:,:,1],cmap='gray')
c = plt.figure(3)
plt.title('frame2')
frame2 = plt.imshow(frame0[:,:,2],cmap='gray')
d = plt.figure(4)
plt.title('frame3')
frame3 = plt.imshow(frame0[:,:,3],cmap='gray')
e = plt.figure(5)
plt.title('frame4')
frame4 = plt.imshow(frame0[:,:,4],cmap='gray')
f = plt.figure(6)
plt.title('mask')
origplot = plt.imshow(mask0,cmap='gray')


plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-eabeaacbecc8> in <module>
#       6 b = plt.figure(2)
#       7 plt.title('frame1')
# ----> 8 frame1 = plt.imshow(frame0[:,:,1],cmap='gray')
#       9 c = plt.figure(3)
#      10 plt.title('frame2')
#
# TypeError: 'AxesImage' object is not subscriptable

# %%
mask0=np.load(os.path.join(mask_dir,masks_files[2347]))
f = plt.figure(6)
plt.title('mask')
origplot = plt.imshow(mask0,cmap='gray')

# %%
from libtiff import TIFF
curpath = '/home/yifanc3/dataset/data'
tif = TIFF.open(curpath + '/mclean_roi.tif')
img = tif.read_image()
import numpy as np
np.max(img[:,:,0])

# %%
import numpy as np
np.max(img[:,:,0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-2-e3c697e7dc62> in <module>
#       1 import numpy as np
# ----> 2 np.max(img[:,:,0])
#
# IndexError: too many indices for array

# %%
np.max(img[:,:,1])

# %%
np.max(img[:,:,2])

# %%
np.max(img[:,:,3])

# %%
np.max(img[:,:,4])
