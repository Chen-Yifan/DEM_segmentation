# %%
from libtiff import TIFF

import os
import random
import re
from PIL import Image
import numpy as np
from shutil import copyfile
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
curpath = '/home/yifanc3/dataset/data'
os.listdir(curpath)
# Out:
# ['5m_grass_waterway_3443.geojson',
#  'README.txt',
#  'cl1.tif',
#  'cl1.tif.aux.xml',
#  'cl2.tif',
#  'cl3.tif',
#  'mclean_roi.tif',
#  'mclean_roi_aspect.tif',
#  'mclean_roi_mb.tif',
#  'mclean_roi_rough.tif',
#  'mclean_roi_slope.tif',
#  'mclean_roi_tpi.tif',
#  'mclean_roi_tri.tif',
#  'annotated_mask.npy',
#  'frames_64',
#  'frames_64_out',
#  'masks_64',
#  'masks_64_out',
#  'annotated_mask.tif',
#  'annotations_64',
#  'annotations_64_out',
#  'frames_128',
#  'masks_128',
#  'annotations_128',
#  'annotations_128_out',
#  'masks_128_out',
#  'frames_128_out',
#  'selected_64',
#  'selected_128',
#  'frames_128_overlap',
#  'masks_128_overlap',
#  'annotations_128_overlap',
#  'annotations_128_overlap_out',
#  'frames_128_overlap_out',
#  'masks_128_overlap_out',
#  'selected_128_overlap']

# %%
tif = TIFF.open(curpath + '/mclean_roi.tif')
img = tif.read_image()

# %%
plt.title('mclean_roi_mb')
origplot = plt.imshow(img[:,:],cmap='gray')

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# %%
origplot = plt.imshow(img[:,:,1],cmap='gray')
